# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/blu-bridge25/Study/Code/TensorParallelismBeta/DTensor/Training__log348.csv')

plt.plot(df['step'][:600].to_numpy(), df['loss'][:600].to_numpy())

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss')
plt.savefig('loss_curve.png')
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[62], line 4
#       1 import pandas as pd
#       2 import matplotlib.pyplot as plt
# ----> 4 df = pd.read_csv('/home/blu-bridge25/Study/Code/TensorParallelismBeta/DTensor/Training__log348.csv')
#       6 plt.plot(df['step'][:600].to_numpy(), df['loss'][:600].to_numpy())
#       8 plt.xlabel('Step')
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/blu-bridge25/Study/Code/TensorParallelismBeta/DTensor/Training__log351.csv')

plt.plot(df['step'].to_numpy(), df['loss'].to_numpy())

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss')
plt.savefig('loss_curve.png')

# %%
import numpy as np
import os

def convert_npy_to_bin(npy_filename, bin_filename):
    """
    Converts a .npy file (which has a NumPy header) to a raw binary .bin file 
    (without a header).

    Args:
        npy_filename (str): The path to the input .npy file.
        bin_filename (str): The path to the output .bin file.
    """
    try:
        # 1. Load the data from the .npy file into a NumPy array
        # np.load automatically handles the .npy header
        data = np.load(npy_filename)
        print(f"Successfully loaded data from {npy_filename} with shape: {data.shape} and dtype: {data.dtype}")

        # 2. Write the raw data to the .bin file using tofile()
        # This method writes the array data as a raw stream of bytes
        with open(bin_filename, 'wb') as f:
            data.tofile(f)
        
        print(f"Successfully wrote raw binary data to {bin_filename}")

    except FileNotFoundError:
        print(f"Error: The file {npy_filename} was not found.")
    except Exception as e:
        print(f"An error occurred: {e}")

# --- Example Usage ---
if __name__ == "__main__":
    # 1. Create a sample .npy file first for demonstration
    # # sample_data = np.array([1.5, 2.7, 3.14, 4.0], dtype=np.float32)
    # sample_npy_filename = 'sample_data.npy'
    # np.save(sample_npy_filename, sample_data)
    # print(f"Created sample file: {sample_npy_filename}")

    # 2. Convert the created .npy file to a .bin file
    output_bin_filename = 'val_shard_00000.bin'
    convert_npy_to_bin("/home/blubridge-035/Desktop/Backup/parallelism/script11/val_shard_00000.npy", output_bin_filename)

    # Optional: Verify the output by reading the .bin file back
    if os.path.exists(output_bin_filename):
        # We must specify the exact dtype and shape to read raw binary correctly
        # In this case, float32 and shape of (4,)
        with open(output_bin_filename, 'rb') as f:
            loaded_data = np.fromfile(f, dtype=np.float32)
        print(f"\nVerification: Loaded data from {output_bin_filename} as: {loaded_data}")
        # print(f"Verification successful: {np.array_equal(sample_data, loaded_data)}")
        
        # Clean up the sample files
        # os.remove(sample_npy_filename)
        # os.remove(output_bin_filename)
        # print("Cleaned up sample files.")
# Out:
# Successfully loaded data from /home/blubridge-035/Desktop/Backup/parallelism/script11/val_shard_00000.npy with shape: (99999585,) and dtype: uint16
# Successfully wrote raw binary data to val_shard_00000.bin
#
# Verification: Loaded data from val_shard_00000.bin as: [3.2782974e-38 2.3271013e-39 1.7458686e-33 ... 2.0501844e-35 3.4094890e-05
#  1.0215507e-32]

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/blu-bridge25/Study/Code/TensorParallelismBeta/DTensor/log_nnmodseq_bluwerp_lossscale.csv')

plt.plot(df['step'].to_numpy(), df['loss'].to_numpy())

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss')
plt.savefig('loss_curve.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/blu-bridge25/Study/Code/TensorParallelismBeta/DTensor/Training__log367.csv')

plt.plot(df['step'].to_numpy(), df['loss'].to_numpy())

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss')
plt.savefig('loss_curve.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/blu-bridge25/Study/Code/TensorParallelismBeta/DTensor/Training__log384.csv')

plt.plot(df['step'].to_numpy(), df['loss'].to_numpy())

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss')
plt.savefig('loss_curve.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/blu-bridge25/Study/Code/TensorParallelismBeta/DTensor/log_tensor_parallel_no_embedding_sharding.csv')

plt.plot(df['step'].to_numpy(), df['loss'].to_numpy())

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss')
plt.savefig('loss_curve.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/blu-bridge25/Study/Code/TensorParallelismBeta/gpt/Training__log1.csv')

plt.plot(df['step'].to_numpy(), df['loss'].to_numpy())

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss')
plt.savefig('loss_curve.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/blu-bridge25/Study/Code/TensorParallelismBeta/gpt/Training__log5.csv')

plt.plot(df['step'].to_numpy(), df['loss'].to_numpy())

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss')
plt.savefig('loss_curve.png')

# %%
df = pd.read_csv('/home/blu-bridge25/Study/Code/TensorParallelismBeta/gpt/Training__log6.csv')

plt.plot(df['step'].to_numpy(), df['loss'].to_numpy())

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss')
plt.savefig('loss_curve.png')
/home/blu-bridge25/Study/Code/TensorParallelismBeta/gpt/log_tp/PyTorch_Training__log1.csv
