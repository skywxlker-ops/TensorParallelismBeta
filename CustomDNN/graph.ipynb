# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/training_logs/customdnn_training_log9.csv')

plt.plot(df['step'].to_numpy(), df['loss'].to_numpy())

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss')
plt.savefig('loss_curve.png')

print("Maximum throughput: ", df['tok_per_sec'].max())
print("Avg. Throughput:",df['tok_per_sec'].mean())
print("Min Train Loss:",df['loss'].min())
print("Average loss: ", df['loss'].mean())
print("Max Grad Norm: ", df['grad_norm'].max())
print("Min Val Loss:",df['val_loss'].where(df['val_loss']!=(-1)).min())
# Out:
# Maximum throughput:  51216.724211
# Avg. Throughput: 50253.604432065724
# Min Train Loss: 8.552527
# Average loss:  9.150969993428259
# Max Grad Norm:  69.879166
# Min Val Loss: 8.823376

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/training_logs/customdnn_training_log6.csv')

plt.plot(df['step'].to_numpy(), df['loss'].to_numpy())

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss')
plt.savefig('loss_curve.png')

print("Maximum throughput: ", df['tok_per_sec'].max())
print("Avg. Throughput:",df['tok_per_sec'].mean())
print("Min Train Loss:",df['loss'].min())
print("Average loss: ", df['loss'].mean())
print("Max Grad Norm: ", df['grad_norm'].max())
print("Min Val Loss:",df['val_loss'].where(df['val_loss']!=(-1)).min())
# Out:
# Maximum throughput:  51508.61173
# Avg. Throughput: 50799.76764209758
# Min Train Loss: 7.67832
# Average loss:  8.3591183000564
# Max Grad Norm:  6.312515
# Min Val Loss: 8.11644

# %%
import pandas as pd
import matplotlib.pyplot as plt

df9 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/training_logs/customdnn_training_log9.csv')
df2 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/training_logs/customdnn_training_log2.csv')

plt.figure(figsize=(10, 6))
plt.plot(df9['step'].to_numpy(), df9['loss'].to_numpy(), label='Log 9', color='blue', alpha=0.7)
plt.plot(df2['step'].to_numpy(), df2['loss'].to_numpy(), label='Log 2', color='red', alpha=0.7)

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss Comparison')
plt.legend()
plt.grid(True)
plt.savefig('combined_loss_curve.png')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/training_logs/customdnn_training_log5.csv')

plt.plot(df['step'].to_numpy(), df['loss'].to_numpy())

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss')
plt.savefig('loss_curve.png')

print("Maximum throughput: ", df['tok_per_sec'].max())
print("Avg. Throughput:",df['tok_per_sec'].mean())
print("Min Train Loss:",df['loss'].min())
print("Average loss: ", df['loss'].mean())
print("Max Grad Norm: ", df['grad_norm'].max())
print("Min Val Loss:",df['val_loss'].where(df['val_loss']!=(-1)).min())
# Out:
# Maximum throughput:  54026.784608
# Avg. Throughput: 52784.976082639805
# Min Train Loss: 7.550022
# Average loss:  8.31919936935287
# Max Grad Norm:  5.386446
# Min Val Loss: 8.019195

# %%
import pandas as pd
import matplotlib.pyplot as plt

df5 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/training_logs/customdnn_training_log5.csv')
df2 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/training_logs/customdnn_training_log6.csv')

plt.figure(figsize=(10, 6))
plt.plot(df5['step'].to_numpy(), df5['loss'].to_numpy(), label='2 GPUs', color='blue', alpha=0.7)
plt.plot(df2['step'].to_numpy(), df2['loss'].to_numpy(), label='1 GPU', color='red', alpha=0.7)

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss Comparison')
plt.legend()
plt.grid(True)
plt.savefig('combined_loss_curve.png')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df9 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/training_logs/customdnn_training_log9.csv')
df2 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/training_logs/customdnn_training_log5.csv')

plt.figure(figsize=(10, 6))
plt.plot(df9['step'].to_numpy(), df9['loss'].to_numpy(), label='old run', color='blue', alpha=0.7)
plt.plot(df2['step'].to_numpy(), df2['loss'].to_numpy(), label='new run', color='red', alpha=0.7)

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss Comparison')
plt.legend()
plt.grid(True)
plt.savefig('combined_loss_curve.png')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/training_logs/customdnn_training_log5.csv')

plt.plot(df['step'].to_numpy(), df['tok_per_sec'].to_numpy())

plt.xlabel('Step')
plt.ylabel('Throughput')
plt.title('Throughput')


print("Maximum throughput: ", df['tok_per_sec'].max())
print("Avg. Throughput:",df['tok_per_sec'].mean())
# Out:
# Maximum throughput:  54026.784608
# Avg. Throughput: 52784.976082639805

# %%
import pandas as pd
import matplotlib.pyplot as plt

df6 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/training_logs/customdnn_training_log6.csv')
df5 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/training_logs/customdnn_training_log5.csv')

plt.figure(figsize=(10, 6))
plt.plot(df6['step'].to_numpy(), df6['tok_per_sec'].to_numpy(), label='1 gpu', color='blue', alpha=0.7)
plt.plot(df5['step'].to_numpy(), df5['tok_per_sec'].to_numpy(), label='2 gpu', color='red', alpha=0.7)

plt.xlabel('Step')
plt.ylabel('tok_per_sec')
plt.title('Training tok_per_sec Comparison')
plt.legend()
plt.grid(True)
plt.savefig('combined_loss_curve.png')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/training_logs/customdnn_training_log10.csv')

plt.plot(df['step'].to_numpy(), df['loss'].to_numpy())

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss')
plt.savefig('loss_curve.png')

print("Maximum throughput: ", df['tok_per_sec'].max())
print("Avg. Throughput:",df['tok_per_sec'].mean())
print("Min Train Loss:",df['loss'].min())
print("Average loss: ", df['loss'].mean())
print("Max Grad Norm: ", df['grad_norm'].max())
print("Min Val Loss:",df['val_loss'].where(df['val_loss']!=(-1)).min())
# Out:
# Maximum throughput:  52438.150787
# Avg. Throughput: 51118.96916365323
# Min Train Loss: 7.623512
# Average loss:  8.367904835775336
# Max Grad Norm:  5.635576
# Min Val Loss: 8.072198

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/training_logs/customdnn_training_log10.csv')

plt.plot(df['step'].to_numpy(), df['tok_per_sec'].to_numpy())

plt.xlabel('Step')
plt.ylabel('Throughput')
plt.title('Throughput')


print("Maximum throughput: ", df['tok_per_sec'].max())
print("Avg. Throughput:",df['tok_per_sec'].mean())
# Out:
# Maximum throughput:  52438.150787
# Avg. Throughput: 51118.96916365323

# %%
import pandas as pd
import matplotlib.pyplot as plt

df5 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/training_logs/customdnn_training_log5.csv')
df2 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/training_logs/customdnn_training_log10.csv')

plt.figure(figsize=(10, 6))
plt.plot(df5['step'].to_numpy(), df5['loss'].to_numpy(), label='without sync_w_autograd', color='blue', alpha=0.7)
plt.plot(df2['step'].to_numpy(), df2['loss'].to_numpy(), label='with sync_w_autpgrad', color='red', alpha=0.7)

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss Comparison')
plt.legend()
plt.grid(True)
plt.savefig('combined_loss_curve.png')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df6 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/training_logs/customdnn_training_log10.csv')
df5 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/training_logs/customdnn_training_log5.csv')

plt.figure(figsize=(10, 6))
plt.plot(df6['step'].to_numpy(), df6['tok_per_sec'].to_numpy(), label='sync_w_autograd', color='blue', alpha=0.7)
plt.plot(df5['step'].to_numpy(), df5['tok_per_sec'].to_numpy(), label='without sync_w_autograd', color='red', alpha=0.7)

plt.xlabel('Step')
plt.ylabel('tok_per_sec')
plt.title('Training tok_per_sec Comparison')
plt.legend()
plt.grid(True)
plt.savefig('combined_loss_curve.png')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/training_logs/customdnn_training_log11.csv')

plt.plot(df['step'].to_numpy(), df['loss'].to_numpy())

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss')
plt.savefig('loss_curve.png')

print("Maximum throughput: ", df['tok_per_sec'].max())
print("Avg. Throughput:",df['tok_per_sec'].mean())
print("Min Train Loss:",df['loss'].min())
print("Average loss: ", df['loss'].mean())
print("Max Grad Norm: ", df['grad_norm'].max())
print("Min Val Loss:",df['val_loss'].where(df['val_loss']!=(-1)).min())
# Out:
# Maximum throughput:  53380.521527
# Avg. Throughput: 51816.24583232479
# Min Train Loss: 7.560038
# Average loss:  8.333666900488401
# Max Grad Norm:  5.271677
# Min Val Loss: 8.034204

# %%
import pandas as pd
import matplotlib.pyplot as plt

df5 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/Naive/naive_run_log1.csv')
df2 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/training_logs/customdnn_training_log5.csv')
# df3 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/training_logs/customdnn_training_log18.csv')

plt.figure(figsize=(10, 6))
plt.plot(df5['step'].to_numpy(), df5['loss'].to_numpy(), label='with sync', color='blue', alpha=0.5)
plt.plot(df2['step'].to_numpy(), df2['loss'].to_numpy(), label='without any sync', color='red', alpha=0.5)
# plt.plot(df3['step'].to_numpy(), df3['loss'].to_numpy(), label='without any sync', color='green', alpha=1)

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss Comparison')
plt.legend()
plt.grid(True)
plt.savefig('combined_loss_curve.png')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df6 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/training_logs/customdnn_training_log10.csv')
df5 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/training_logs/customdnn_training_log11.csv')

plt.figure(figsize=(10, 6))
plt.plot(df6['step'].to_numpy(), df6['tok_per_sec'].to_numpy(), label='sync_w_autograd', color='blue', alpha=0.7)
plt.plot(df5['step'].to_numpy(), df5['tok_per_sec'].to_numpy(), label='with sync', color='violet', alpha=0.7)

print("max throughput - with sync = ", df5['tok_per_sec'].max())
print("max throughput - with sync_w_autograd = ", df6['tok_per_sec'].max())
print("average throughput - with sync_w_autograd = ", df6['tok_per_sec'].mean())
print("average throughput - with sync = ", df5['tok_per_sec'].mean())
plt.xlabel('Step')
plt.ylabel('tok_per_sec')
plt.title('Training tok_per_sec Comparison')
plt.legend()
plt.grid(True)
plt.savefig('combined_loss_curve.png')
plt.show()
# Out:
# max throughput - with sync =  53380.521527
# max throughput - with sync_w_autograd =  52438.150787
# average throughput - with sync_w_autograd =  51118.96916365323
# average throughput - with sync =  51816.24583232479

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/training_logs/customdnn_training_log14.csv')

plt.plot(df['step'].to_numpy(), df['loss'].to_numpy())

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss')
plt.savefig('loss_curve.png')

print("Maximum throughput: ", df['tok_per_sec'].max())
print("Avg. Throughput:",df['tok_per_sec'].mean())
print("Min Train Loss:",df['loss'].min())
print("Average loss: ", df['loss'].mean())
print("Max Grad Norm: ", df['grad_norm'].max())
print("Min Val Loss:",df['val_loss'].where(df['val_loss']!=(-1)).min())
# Out:
# Maximum throughput:  50509.560033
# Avg. Throughput: 49268.50267387366
# Min Train Loss: 7.578609
# Average loss:  8.30123893965031
# Max Grad Norm:  5.463686
# Min Val Loss: 8.047386

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/training_logs/customdnn_training_log18.csv')

plt.plot(df['step'].to_numpy(), df['loss'].to_numpy())

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss')
plt.savefig('loss_curve.png')

print("Maximum throughput: ", df['tok_per_sec'].max())
print("Avg. Throughput:",df['tok_per_sec'].mean())
print("Min Train Loss:",df['loss'].min())
print("Average loss: ", df['loss'].mean())
print("Max Grad Norm: ", df['grad_norm'].max())
print("Min Val Loss:",df['val_loss'].where(df['val_loss']!=(-1)).min())
# Out:
# Maximum throughput:  49127.03169
# Avg. Throughput: 47675.18036565595
# Min Train Loss: 7.521581
# Average loss:  8.299862650874225
# Max Grad Norm:  20.338572
# Min Val Loss: 8.008707

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/Naive/naive_run_log1.csv')

plt.plot(df['step'].to_numpy(), df['loss'].to_numpy())

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss')
# plt.savefig('loss_curve.png')

print("Maximum throughput: ", df['tok_per_sec'].max())
print("Avg. Throughput:",df['tok_per_sec'].mean())
print("Min Train Loss:",df['loss'].min())
print("Average loss: ", df['loss'].mean())
print("Max Grad Norm: ", df['grad_norm'].max())
print("Min Val Loss:",df['val_loss'].where(df['val_loss']!=(-1)).min())
# Out:
# Maximum throughput:  2220.7499
# Avg. Throughput: 1957.43288025
# Min Train Loss: 10.881292
# Average loss:  10.885018500000001
# Max Grad Norm:  2.475993
# Min Val Loss: 10.888095

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/Naive/naive_run_log1.csv')

plt.plot(df['step'].to_numpy(), df['tok_per_sec'].to_numpy())

plt.xlabel('Step')
plt.ylabel('Throughput')
plt.title('Throughput')


print("Maximum throughput: ", df['tok_per_sec'].max())
print("Avg. Throughput:",df['tok_per_sec'].mean())
# Out:
# Maximum throughput:  2220.7499
# Avg. Throughput: 1957.43288025

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/Naive/naive_run_log2.csv')

plt.plot(df['step'].to_numpy(), df['loss'].to_numpy())

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss')
# plt.savefig('loss_curve.png')

print("Maximum throughput: ", df['tok_per_sec'].max())
print("Avg. Throughput:",df['tok_per_sec'].mean())
print("Min Train Loss:",df['loss'].min())
print("Average loss: ", df['loss'].mean())
print("Max Grad Norm: ", df['grad_norm'].max())
print("Min Val Loss:",df['val_loss'].where(df['val_loss']!=(-1)).min())
# Out:
# Maximum throughput:  44399.13818
# Avg. Throughput: 42867.53100228163
# Min Train Loss: 6.499729
# Average loss:  7.1942130812557705
# Max Grad Norm:  5.310605
# Min Val Loss: 6.934966

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/Naive/naive_run_log2.csv')

plt.plot(df['step'].to_numpy(), df['tok_per_sec'].to_numpy())

plt.xlabel('Step')
plt.ylabel('Throughput')
plt.title('Throughput')


print("Maximum throughput: ", df['tok_per_sec'].max())
print("Avg. Throughput:",df['tok_per_sec'].mean())
# Out:
# Maximum throughput:  44399.13818
# Avg. Throughput: 42867.53100228163

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/Naive/naive_run_log3.csv')

plt.plot(df['step'].to_numpy(), df['loss'].to_numpy())

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss')
# plt.savefig('loss_curve.png')

print("Maximum throughput: ", df['tok_per_sec'].max())
print("Avg. Throughput:",df['tok_per_sec'].mean())
print("Min Train Loss:",df['loss'].min())
print("Average loss: ", df['loss'].mean())
print("Max Grad Norm: ", df['grad_norm'].max())
print("Min Val Loss:",df['val_loss'].where(df['val_loss']!=(-1)).min())
# Out:
# Maximum throughput:  47013.148155
# Avg. Throughput: 45607.768382315786
# Min Train Loss: 6.42716
# Average loss:  7.124624123422591
# Max Grad Norm:  6.397778
# Min Val Loss: 6.875303

# %%
import pandas as pd
import matplotlib.pyplot as plt

df1 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/Naive/naive_run_log2.csv')
df2 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/Naive/naive_run_log4.csv')
# df3 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/training_logs/customdnn_training_log18.csv')

plt.figure(figsize=(10, 6))
plt.plot(df1['step'].to_numpy(), df1['loss'].to_numpy(), label='Old Run', color='blue', alpha=0.8)
plt.plot(df2['step'].to_numpy(), df2['loss'].to_numpy(), label='New Run', color='red', alpha=0.8)
# plt.plot(df3['step'].to_numpy(), df3['loss'].to_numpy(), label='without any sync', color='green', alpha=1)

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss Comparison')
plt.legend()
plt.grid(True)
# plt.savefig('combined_loss_curve.png')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df1 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/Naive/naive_run_log2.csv')
df2 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/Naive/naive_run_log4.csv')

plt.figure(figsize=(10, 6))
plt.plot(df1['step'].to_numpy(), df1['tok_per_sec'].to_numpy(), label='Old Run', color='blue', alpha=0.8)
plt.plot(df2['step'].to_numpy(), df2['tok_per_sec'].to_numpy(), label='New Run', color='red', alpha=0.8)

print("max throughput - Old Run = ", df1['tok_per_sec'].max())
print("max throughput - New Run = ", df2['tok_per_sec'].max())
print("average throughput - Old Run = ", df1['tok_per_sec'].mean())
print("average throughput - New Run = ", df2['tok_per_sec'].mean())
plt.xlabel('Step')
plt.ylabel('tok_per_sec')
plt.title('Training tok_per_sec Comparison')
plt.legend()
plt.grid(True)
# plt.savefig('combined_loss_curve.png')
plt.show()
# Out:
# max throughput - Old Run =  44399.13818
# max throughput - New Run =  44375.754565
# average throughput - Old Run =  42867.53100228163
# average throughput - New Run =  42686.10157907386

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/Naive/naive_run_log4.csv')

plt.plot(df['step'].to_numpy(), df['loss'].to_numpy())

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss')
# plt.savefig('loss_curve.png')

print("Maximum throughput: ", df['tok_per_sec'].max())
print("Avg. Throughput:",df['tok_per_sec'].mean())
print("Min Train Loss:",df['loss'].min())
print("Average loss: ", df['loss'].mean())
print("Max Grad Norm: ", df['grad_norm'].max())
print("Min Val Loss:",df['val_loss'].where(df['val_loss']!=(-1)).min())
# Out:
# Maximum throughput:  44375.754565
# Avg. Throughput: 42686.10157907386
# Min Train Loss: 5.586121
# Average loss:  6.275331763377927
# Max Grad Norm:  2.894572
# Min Val Loss: 5.82004

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/Naive/naive_run_log5.csv')

plt.plot(df['step'].to_numpy(), df['loss'].to_numpy())

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss')
# plt.savefig('loss_curve.png')

print("Maximum throughput: ", df['tok_per_sec'].max())
print("Avg. Throughput:",df['tok_per_sec'].mean())
print("Min Train Loss:",df['loss'].min())
print("Average loss: ", df['loss'].mean())
print("Max Grad Norm: ", df['grad_norm'].max())
print("Min Val Loss:",df['val_loss'].where(df['val_loss']!=(-1)).min())
# Out:
# Maximum throughput:  46814.355238
# Avg. Throughput: 46095.37007414832
# Min Train Loss: 5.478022
# Average loss:  6.095494063128004
# Max Grad Norm:  2.851819
# Min Val Loss: 5.729403

# %%
import pandas as pd
import matplotlib.pyplot as plt

df1 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/Naive/naive_run_log4.csv')
df2 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/Naive/naive_run_log5.csv')
# df3 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/training_logs/customdnn_training_log18.csv')

plt.figure(figsize=(10, 6))
plt.plot(df1['step'].to_numpy(), df1['loss'].to_numpy(), label='Old Run', color='blue', alpha=0.8)
plt.plot(df2['step'].to_numpy(), df2['loss'].to_numpy(), label='New Run', color='red', alpha=0.8)
# plt.plot(df3['step'].to_numpy(), df3['loss'].to_numpy(), label='without any sync', color='green', alpha=1)

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss Comparison')
plt.legend()
plt.grid(True)
# plt.savefig('combined_loss_curve.png')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/Naive/naive_run_log8.csv')

plt.plot(df['step'].to_numpy(), df['loss'].to_numpy())

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss')
# plt.savefig('loss_curve.png')

print("Maximum throughput: ", df['tok_per_sec'].max())
print("Avg. Throughput:",df['tok_per_sec'].mean())
print("Min Train Loss:",df['loss'].min())
print("Average loss: ", df['loss'].mean())
print("Max Grad Norm: ", df['grad_norm'].max())
print("Min Val Loss:",df['val_loss'].where(df['val_loss']!=(-1)).min())
# Out:
# Maximum throughput:  18620.942923
# Avg. Throughput: 18461.91026709657
# Min Train Loss: 5.468482
# Average loss:  6.04249083679266
# Max Grad Norm:  4.041865
# Min Val Loss: 5.721704

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/Naive/naive_run_log10.csv')

plt.plot(df['step'].to_numpy(), df['loss'].to_numpy())

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss')
# plt.savefig('loss_curve.png')

print("Maximum throughput: ", df['tok_per_sec'].max())
print("Avg. Throughput:",df['tok_per_sec'].mean())
print("Min Train Loss:",df['loss'].min())
print("Average loss: ", df['loss'].mean())
print("Max Grad Norm: ", df['grad_norm'].max())
print("Min Val Loss:",df['val_loss'].where(df['val_loss']!=(-1)).min())
# Out:
# Maximum throughput:  14958.29576
# Avg. Throughput: 14665.778522556388
# Min Train Loss: 7.217264
# Average loss:  7.889992296892981
# Max Grad Norm:  1.846391
# Min Val Loss: 7.606251

# %%
import pandas as pd
import matplotlib.pyplot as plt

df1 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/Naive/naive_run_log9.csv')
df2 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/Naive/naive_run_log10.csv')
df3 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/Naive/naive_run_log7.csv')
# df3 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/training_logs/customdnn_training_log18.csv')

plt.figure(figsize=(10, 6))
plt.plot(df1['step'].to_numpy(), df1['loss'].to_numpy(), label='Without loss parallel', color='blue', alpha=1)
plt.plot(df2['step'].to_numpy(), df2['loss'].to_numpy(), label='With loss parallel', color='red', alpha=0.8)
plt.plot(df3['step'].to_numpy(), df3['loss'].to_numpy(), label='Control run - without vocab parallel', color='green', alpha=0.6)

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss Comparison')
plt.legend()
plt.grid(True)
# plt.savefig('combined_loss_curve.png')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/Naive/naive_run_log9.csv')

plt.plot(df['step'].to_numpy(), df['loss'].to_numpy())

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss')
# plt.savefig('loss_curve.png')

print("Maximum throughput: ", df['tok_per_sec'].max())
print("Avg. Throughput:",df['tok_per_sec'].mean())
print("Min Train Loss:",df['loss'].min())
print("Average loss: ", df['loss'].mean())
print("Max Grad Norm: ", df['grad_norm'].max())
print("Min Val Loss:",df['val_loss'].where(df['val_loss']!=(-1)).min())
# Out:
# Maximum throughput:  57688.4074
# Avg. Throughput: 56344.79209535501
# Min Train Loss: 5.911328
# Average loss:  6.651463230149597
# Max Grad Norm:  2.675295
# Min Val Loss: 6.257727

# %%
import pandas as pd
import matplotlib.pyplot as plt

df1 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/PyTorch/PyTorch_run_log.csv')
df2 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/Naive/naive_run_log10.csv')

plt.figure(figsize=(10, 6))
plt.plot(df1['step'].to_numpy(), df1['tok_per_sec'].to_numpy(), label='Without loss parallel', color='blue', alpha=0.8)
plt.plot(df2['step'].to_numpy(), df2['tok_per_sec'].to_numpy(), label='With loss parallel', color='red', alpha=0.8)

print("max throughput - Without loss parallel = ", df1['tok_per_sec'].max())
print("max throughput - With loss parallel = ", df2['tok_per_sec'].max())
print("average throughput - Without loss parallel = ", df1['tok_per_sec'].mean())
print("average throughput - With loss parallel = ", df2['tok_per_sec'].mean())
plt.xlabel('Step')
plt.ylabel('tok_per_sec')
plt.title('Training tok_per_sec Comparison')
plt.legend()
plt.grid(True)
# plt.savefig('combined_loss_curve.png')
plt.show()
# Out:
# max throughput - Without loss parallel =  68802.38
# max throughput - With loss parallel =  14958.29576
# average throughput - Without loss parallel =  66710.32970308789
# average throughput - With loss parallel =  14665.778522556388

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/PyTorch_run_log2.csv')

plt.plot(df['step'].to_numpy(), df['loss'].to_numpy())

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss')
# plt.savefig('loss_curve.png')

print("Maximum throughput: ", df['tok_per_sec'].max())
print("Avg. Throughput:",df['tok_per_sec'].mean())
print("Min Train Loss:",df['loss'].min())
print("Average loss: ", df['loss'].mean())
print("Max Grad Norm: ", df['norm'].max())
# print("Min Val Loss:",df['val_loss'].where(df['val_loss']!=(-1)).min())
# Out:
# Maximum throughput:  61073.09
# Avg. Throughput: 59540.36015552995
# Min Train Loss: 5.929145
# Average loss:  6.699289429723502
# Max Grad Norm:  1.8198

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/PyTorch_run_log.csv')

plt.plot(df['step'].to_numpy(), df['loss'].to_numpy())

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss')
# plt.savefig('loss_curve.png')

print("Maximum throughput: ", df['tok_per_sec'].max())
print("Avg. Throughput:",df['tok_per_sec'].mean())
print("Min Train Loss:",df['loss'].min())
print("Average loss: ", df['loss'].mean())
print("Max Grad Norm: ", df['norm'].max())
# print("Min Val Loss:",df['val_loss'].where(df['val_loss']!=(-1)).min())
# Out:
# Maximum throughput:  58724.83
# Avg. Throughput: 57480.52441311853
# Min Train Loss: 5.929145
# Average loss:  6.698685904487918
# Max Grad Norm:  1.8198

# %%
import pandas as pd
import matplotlib.pyplot as plt

# df1 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/Naive/naive_run_log9.csv')
df2 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/Naive/naive_run_log13.csv')
df3 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/PyTorch_run_log3.csv')
# df3 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/training_logs/customdnn_training_log18.csv')

plt.figure(figsize=(10, 6))
# plt.plot(df1['step'].to_numpy(), df1['loss'].to_numpy(), label='Ours',linestyle='-', color='blue', alpha=1)
plt.plot(df2['step'].to_numpy(), df2['loss'].to_numpy(), label='PyTorch', linestyle='-',color='red', alpha=1)
plt.plot(df3['step'].to_numpy(), df3['loss'].to_numpy(), label='Control run - without vocab parallel', color='blue', alpha=0.6)

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss Comparison')
plt.legend()
plt.grid(True)
# plt.savefig('combined_loss_curve.png')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/PyTorch_run_log3.csv')

plt.plot(df['step'].to_numpy(), df['loss'].to_numpy())

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss')
# plt.savefig('loss_curve.png')

print("Maximum throughput: ", df['tok_per_sec'].max())
print("Avg. Throughput:",df['tok_per_sec'].mean())
print("Min Train Loss:",df['loss'].min())
print("Average loss: ", df['loss'].mean())
print("Max Grad Norm: ", df['norm'].max())
# print("Min Val Loss:",df['val_loss'].where(df['val_loss']!=(-1)).min())
# Out:
# Maximum throughput:  56083.91
# Avg. Throughput: 53892.80056962025
# Min Train Loss: 5.929145
# Average loss:  6.698685902761795
# Max Grad Norm:  1.8198

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/Naive/naive_run_log.csv')

plt.plot(df['step'].to_numpy(), df['loss'].to_numpy())

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss')
# plt.savefig('loss_curve.png')

print("Maximum throughput: ", df['tok_per_sec'].max())
print("Avg. Throughput:",df['tok_per_sec'].mean())
print("Min Train Loss:",df['loss'].min())
print("Average loss: ", df['loss'].mean())
print("Max Grad Norm: ", df['grad_norm'].max())
print("Min Val Loss:",df['val_loss'].where(df['val_loss']!=(-1)).min())
# Out:
# Maximum throughput:  50072.09236
# Avg. Throughput: 47796.36751774741
# Min Train Loss: 5.842863
# Average loss:  6.610797277905639
# Max Grad Norm:  2.727534
# Min Val Loss: 6.112973
