# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/attn/attn_run_log.csv')

plt.plot(df['step'].to_numpy(), df['loss'].to_numpy())

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss')
plt.grid(True)
# plt.savefig('loss_curve.png')

print("Maximum throughput: ", df['tok_per_sec'].max())
print("Avg. Throughput:",df['tok_per_sec'].mean())
print("Min Train Loss:",df['loss'].min())
print("Average loss: ", df['loss'].mean())
print("Max Grad Norm: ", df['grad_norm'].max())
print("Min Val Loss:",df['val_loss'].where(df['val_loss']!=(-1)).min())
# Out:
# Maximum throughput:  27181.762008
# Avg. Throughput: 26530.23580052485
# Min Train Loss: 5.02595
# Average loss:  5.93695500763044
# Max Grad Norm:  3.285096
# Min Val Loss: 5.546713

# %%
import pandas as pd
import matplotlib.pyplot as plt

# df1 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/Naive/naive_run_log9.csv')
df2 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/attn/log/log_without_tp.csv')
df3 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/attn/attn_run_log_attn_shard.csv')
# df3 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/training_logs/customdnn_training_log18.csv')

plt.figure(figsize=(10, 6))
# plt.plot(df1['step'].to_numpy(), df1['loss'].to_numpy(), label='Ours',linestyle='-', color='blue', alpha=1)
plt.plot(df2['step'].to_numpy(), df2['value'].to_numpy(), label='Base - Pytorch', linestyle='-',color='red', alpha=1)
plt.plot(df3['step'].to_numpy(), df3['loss'].to_numpy(), label='2 gpus with TP (MLP SHARDING ONLY)', color='blue', alpha=0.85)

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss Comparison')
plt.legend()
plt.grid(True)
# plt.savefig('combined_loss_curve.png')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/attn/attn_run_log.csv')

plt.plot(df['step'].to_numpy(), df['tok_per_sec'].to_numpy())

plt.xlabel('Step')
plt.ylabel('Throughput')
plt.title('Throughput')
plt.grid(True)


print("Maximum throughput: ", df['tok_per_sec'].max())
print("Avg. Throughput:",df['tok_per_sec'].mean())
# Out:
# Maximum throughput:  27181.762008
# Avg. Throughput: 26530.23580052485

# %%
import pandas as pd
import matplotlib.pyplot as plt

# df1 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/Naive/naive_run_log9.csv')
df2 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/attn/attn_run_log.csv')
df3 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/attn/attn_run_log_attn_shard_2.csv')
# df3 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/training_logs/customdnn_training_log18.csv')

plt.figure(figsize=(10, 6))
# plt.plot(df1['step'].to_numpy(), df1['loss'].to_numpy(), label='Ours',linestyle='-', color='blue', alpha=1)
plt.plot(df2['step'].to_numpy(), df2['loss'].to_numpy(), label='With Attention', linestyle='-',color='red', alpha=1)
plt.plot(df3['step'].to_numpy(), df3['loss'].to_numpy(), label='Without Attention', color='blue', alpha=0.85)

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss Comparison')
plt.legend()
plt.grid(True)
# plt.savefig('combined_loss_curve.png')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/attn/attn_run_log_attn_shard.csv')

plt.plot(df['step'].to_numpy(), df['loss'].to_numpy())

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss')
plt.grid(True)
# plt.savefig('loss_curve.png')

print("Maximum throughput: ", df['tok_per_sec'].max())
print("Avg. Throughput:",df['tok_per_sec'].mean())
print("Min Train Loss:",df['loss'].min())
print("Average loss: ", df['loss'].mean())
print("Max Grad Norm: ", df['grad_norm'].max())
print("Min Val Loss:",df['val_loss'].where(df['val_loss']!=(-1)).min())
# Out:
# Maximum throughput:  32915.993863
# Avg. Throughput: 31909.355859241085
# Min Train Loss: 5.581564
# Average loss:  6.288293742232452
# Max Grad Norm:  2.793335
# Min Val Loss: 5.849361

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/attn/attn_run_log_attn_shard_2.csv')

plt.plot(df['step'].to_numpy(), df['loss'].to_numpy())

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss')
plt.grid(True)
# plt.savefig('loss_curve.png')

print("Maximum throughput: ", df['tok_per_sec'].max())
print("Avg. Throughput:",df['tok_per_sec'].mean())
print("Min Train Loss:",df['loss'].min())
print("Average loss: ", df['loss'].mean())
print("Max Grad Norm: ", df['grad_norm'].max())
print("Min Val Loss:",df['val_loss'].where(df['val_loss']!=(-1)).min())
# Out:
# Maximum throughput:  17173.823503
# Avg. Throughput: 16905.348940458876
# Min Train Loss: 5.435707
# Average loss:  6.102879920550038
# Max Grad Norm:  3.463929
# Min Val Loss: 5.687076

# %%
import pandas as pd
import matplotlib.pyplot as plt

# df1 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/Naive/naive_run_log9.csv')
df2 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/attn/attn_run_log_attn_shard.csv')
df3 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/attn/attn_run_log_attn_shard_2.csv')
# df3 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/training_logs/customdnn_training_log18.csv')

plt.figure(figsize=(10, 6))
# plt.plot(df1['step'].to_numpy(), df1['loss'].to_numpy(), label='Ours',linestyle='-', color='blue', alpha=1)
plt.plot(df2['step'].to_numpy(), df2['loss'].to_numpy(), label='Smol', linestyle='-',color='red', alpha=1)
plt.plot(df3['step'].to_numpy(), df3['loss'].to_numpy(), label='Big', color='blue', alpha=0.85)

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss Comparison')
plt.legend()
plt.grid(True)
# plt.savefig('combined_loss_curve.png')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/attn/attn_run_log_attn_shard_2.csv')

plt.plot(df['step'].to_numpy(), df['tok_per_sec'].to_numpy())

plt.xlabel('Step')
plt.ylabel('Throughput')
plt.title('Throughput')
plt.grid(True)


print("Maximum throughput: ", df['tok_per_sec'].max())
print("Avg. Throughput:",df['tok_per_sec'].mean())
# Out:
# Maximum throughput:  17173.823503
# Avg. Throughput: 16905.348940458876

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/attn/attn_run_log_attn_shard_5.csv')

plt.plot(df['step'].to_numpy(), df['dt_ms'].to_numpy())

plt.xlabel('Step')
plt.ylabel('Time (ms)')
plt.title('Time')
plt.grid(True)


print("Maximum time: ", df['dt_ms'].max())
print("Minimum time: ", df['dt_ms'].min())
print("Avg.  Time:",df['dt_ms'].mean())
# Out:
# Maximum time:  7010.304199
# Minimum time:  3864.919678
# Avg.  Time: 3925.122267576378

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/attn/attn_run_log_attn_shard_5.csv')

plt.plot(df['step'].to_numpy(), df['loss'].to_numpy())

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss')
plt.grid(True)
# plt.savefig('loss_curve.png')

print("Maximum throughput: ", df['tok_per_sec'].max())
print("Avg. Throughput:",df['tok_per_sec'].mean())
print("Min Train Loss:",df['loss'].min())
print("Average loss: ", df['loss'].mean())
print("Max Grad Norm: ", df['grad_norm'].max())
print("Min Val Loss:",df['val_loss'].where(df['val_loss']!=(-1)).min())
# Out:
# Maximum throughput:  33913.253296
# Avg. Throughput: 33498.00740612756
# Min Train Loss: 4.677065
# Average loss:  5.746389137401574
# Max Grad Norm:  2.727313
# Min Val Loss: 5.481697

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/attn/attn_run_log_attn_shard_7.csv')

plt.plot(df['step'].to_numpy(), df['loss'].to_numpy())

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss')
plt.grid(True)
# plt.savefig('loss_curve.png')

print("Maximum throughput: ", df['tok_per_sec'].max())
print("Avg. Throughput:",df['tok_per_sec'].mean())
print("Min Train Loss:",df['loss'].min())
print("Average loss: ", df['loss'].mean())
print("Max Grad Norm: ", df['grad_norm'].max())
print("Min Val Loss:",df['val_loss'].where(df['val_loss']!=(-1)).min())
# Out:
# Maximum throughput:  33085.456
# Avg. Throughput: 32106.587000086307
# Min Train Loss: 5.530688
# Average loss:  6.183873530494822
# Max Grad Norm:  2.751216
# Min Val Loss: 5.767478

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/attn/attn_run_log_pytorch_tp.csv')

plt.plot(df['step'].to_numpy(), df['loss'].to_numpy())

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss')
plt.grid(True)
# plt.savefig('loss_curve.png')

print("Maximum throughput: ", df['tok_per_sec'].max())
print("Avg. Throughput:",df['tok_per_sec'].mean())
print("Min Train Loss:",df['loss'].min())
print("Average loss: ", df['loss'].mean())
print("Max Grad Norm: ", df['grad_norm'].max())
print("Min Val Loss:",df['val_loss'].where(df['val_loss']!=(-1)).min())
# Out:
# Maximum throughput:  30366.62
# Avg. Throughput: 29364.50158227848
# Min Train Loss: 4.781475
# Average loss:  5.652110685270426
# Max Grad Norm:  3.328487
# Min Val Loss: 4.996601

# %%
import pandas as pd
import matplotlib.pyplot as plt

# df1 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/Naive/naive_run_log9.csv')
df2 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/attn/attn_run_log_attn_shard_8.csv')
df3 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/attn/attn_run_log_pytorch_tp.csv')
# df3 = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/TensorParallel/CustomDNN/gpt2_tests/training_logs/customdnn_training_log18.csv')

plt.figure(figsize=(10, 6))
# plt.plot(df1['step'].to_numpy(), df1['loss'].to_numpy(), label='Ours',linestyle='-', color='blue', alpha=1)
plt.plot(df2['step'].to_numpy(), df2['loss'].to_numpy(), label='2 gpus with TP (MLP  & Attention SHARDING ONLY)', linestyle='-',color='red', alpha=1)
plt.plot(df3['step'].to_numpy(), df3['loss'].to_numpy(), label='PyTorch TP - MLP + Attention Parallel', color='blue', alpha=0.85)

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss Comparison')
plt.legend()
plt.grid(True)
# plt.savefig('combined_loss_curve.png')
plt.show()
