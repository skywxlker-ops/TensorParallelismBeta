# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/Tensor-Parallel/CustomDNN/gpt2_tests/training_logs/customdnn_training_log1.csv')

plt.plot(df['step'].to_numpy(), df['loss'].to_numpy())

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss')
plt.savefig('loss_curve.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/Tensor-Parallel/CustomDNN/gpt2_tests/training_logs/customdnn_training_log1.csv')

plt.plot(df['step'].to_numpy(), df['tok_per_sec'].to_numpy())

plt.xlabel('Step')
plt.ylabel('Tok/sec')
plt.title('Throughput')
# plt.savefig('loss_curve.png')
# Out:
# Text(0.5, 1.0, 'Throughput')

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/Tensor-Parallel/CustomDNN/gpt2_tests/training_logs/customdnn_training_log3.csv')

plt.plot(df['step'].to_numpy(), df['loss'].to_numpy())

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss')
plt.savefig('loss_curve.png')

print("Maximum throughput: ", df['tok_per_sec'].max())
print("Avg. Throughput:",df['tok_per_sec'].mean())
print("Min Train Loss:",df['loss'].min())
print("Average loss: ", df['loss'].mean())
print("Max Grad Norm: ", df['grad_norm'].max())
print("Min Val Loss:",df['val_loss'].where(df['val_loss']!=(-1)).min())
# Out:
# Maximum throughput:  49257.501969
# Avg. Throughput: 48217.77379421001
# Min Train Loss: 6.455859
# Average loss:  7.178418885225885
# Max Grad Norm:  24.580999
# Min Val Loss: 6.952484

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/Tensor-Parallel/CustomDNN/gpt2_tests/training_logs/customdnn_training_log1.csv')

plt.plot(df['step'].to_numpy(), df['tok_per_sec'].to_numpy())

plt.xlabel('Step')
plt.ylabel('Tok/sec')
plt.title('Throughput')
# plt.savefig('loss_curve.png')


print("Maximum throughput: ", df['tok_per_sec'].max())
print("Min Throughput:",df['tok_per_sec'].min())
print("Avg. Throughput:",df['tok_per_sec'].mean())
# Out:
# Maximum throughput:  48798.044409
# Min Throughput: 25819.567377
# Avg. Throughput: 46527.172801487955

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/blu-bridge005/Desktop/Anuj@BluBridge/Tensor-Parallel/CustomDNN/gpt2_tests/training_logs/customdnn_training_log7.csv')

plt.plot(df['step'].to_numpy(), df['loss'].to_numpy())

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss')
plt.savefig('loss_curve.png')

print("Maximum throughput: ", df['tok_per_sec'].max())
print("Avg. Throughput:",df['tok_per_sec'].mean())
print("Min Train Loss:",df['loss'].min())
print("Average loss: ", df['loss'].mean())
print("Max Grad Norm: ", df['grad_norm'].max())
print("Min Val Loss:",df['val_loss'].where(df['val_loss']!=(-1)).min())
# Out:
# Maximum throughput:  20705.153059
# Avg. Throughput: 19449.057157
# Min Train Loss: 11.213418
# Average loss:  11.28772877777778
# Max Grad Norm:  1028.639893
# Min Val Loss: 11.326404
