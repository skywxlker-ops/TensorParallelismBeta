# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/blu-bridge25/Study/Code/TensorParallelismBeta/gpt/log_tp/PyTorch_Training__log2.csv')

plt.plot(df['step'][:1200].to_numpy(), df['loss'][:1200].to_numpy())

plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training Loss')
plt.savefig('loss_curve.png')
